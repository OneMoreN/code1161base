# %%
# General syntax to import a library but no functions:
# %matplotlib inline

import datetime as dt
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style

style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# # NSW Transport Opal Data tap on/off 2016
# 25 July - 31 July and 08 August - 14 Auguest

# %%
dfAug = pd.read_csv('time-loc_20160808-14.csv') #Read the csv of opal data from 08/08/2016 to 14/08/2016
dfJul = pd.read_csv('time-loc_20160725-31.csv') #Read the csv of opal data from 25/07/2016 to 31/07/2016

# %%
dfAug.head()
# Out:
#   mode        date tap   time   loc  count
# 0  bus  20160809.0  on  02:30  2000   81.0
# 1  bus  20160809.0  on  13:30  2095   93.0
# 2  bus  20160809.0  on  13:30  2097   33.0
# 3  bus  20160809.0  on  13:30  2090   22.0
# 4  bus  20160809.0  on  13:30  2093   19.0

# %%
if dfAug['date'].dtype == "float64":
    dfAug['date'] = pd.to_datetime(dfAug['date'].astype(str), format = '%Y%m%d')
if dfJul['date'].dtype == "float64":
    dfJul['date'] = pd.to_datetime(dfJul['date'].astype(str), format = '%Y%m%d')

dfAug.head()
# Out:
#   mode       date tap   time   loc  count
# 0  bus 2016-08-09  on  02:30  2000   81.0
# 1  bus 2016-08-09  on  13:30  2095   93.0
# 2  bus 2016-08-09  on  13:30  2097   33.0
# 3  bus 2016-08-09  on  13:30  2090   22.0
# 4  bus 2016-08-09  on  13:30  2093   19.0

# %%
tapOnAug = dfAug.groupby('tap').aggregate(sum)
tapOnJul = dfJul.groupby('tap').aggregate(sum)
# Out:
#           count
# tap
# off  11840393.0
# on   11839048.0

# %%
tapOnJul['Key'] = 'July'
tapOnAug['Key'] = 'August'

DF = pd.concat([tapOnJul,tapOnAug],keys=['July','August'])

DFGroup = DF.groupby(['tap','Key'])

DFGPlot = DFGroup.sum().unstack('Key').plot(kind='bar')

# %%
tapDayJul = dfJul.groupby(['date', 'mode']).aggregate(sum)
tapDayJul.reset_index(inplace = True)
tapDayJul.head()
# Out:
#         date       mode      count
# 0 2016-07-25        bus  1682097.0
# 1 2016-07-25      ferry    42639.0
# 2 2016-07-25  lightrail    60121.0
# 3 2016-07-25      train  2196386.0
# 4 2016-07-26        bus  1707590.0

# %%
tapDayAug = dfAug.groupby(['date', 'mode']).aggregate(sum)
tapDayAug.reset_index(inplace = True)
tapDayAug.head()
# Out:
#         date       mode      count
# 0 2016-08-08        bus  1762973.0
# 1 2016-08-08      ferry    57816.0
# 2 2016-08-08  lightrail    61973.0
# 3 2016-08-08      train  2333292.0
# 4 2016-08-09        bus  1792732.0

# %%
busJul = tapDayJul[tapDayJul['mode'] == "bus"]
ferryJul = tapDayJul[tapDayJul['mode'] == "ferry"]
lightrailJul = tapDayJul[tapDayJul['mode'] == "lightrail"]
trainJul = tapDayJul[tapDayJul['mode'] == "train"]

width = 10
height = 6
plt.figure(figsize=(width, height))

plt.plot(busJul['date'], busJul['count'], label='Bus')
plt.plot(busJul['date'], ferryJul['count'], label='Ferry')
plt.plot(busJul['date'], lightrailJul['count'], label='Light Rail')
plt.plot(busJul['date'], trainJul['count'], label='Train')

plt.xlabel('Date')
plt.ylabel('Taps')
plt.title('Amount of Taps for Each Transport Type\n July')
plt.legend()
plt.show()

# %%
busAug = tapDayAug[tapDayAug['mode'] == "bus"]
ferryAug = tapDayAug[tapDayAug['mode'] == "ferry"]
lightrailAug = tapDayAug[tapDayAug['mode'] == "lightrail"]
trainAug = tapDayAug[tapDayAug['mode'] == "train"]

width = 10
height = 6
plt.figure(figsize=(width, height))

plt.plot(busAug['date'], busAug['count'], label='Bus')
plt.plot(busAug['date'], ferryAug['count'], label='Ferry')
plt.plot(busAug['date'], lightrailAug['count'], label='Light Rail')
plt.plot(busAug['date'], trainAug['count'], label='Train')

plt.xlabel('Date')
plt.ylabel('Taps')
plt.title('Amount of Taps for Each Transport Type\n August')
plt.legend()
plt.show()

# %%
tapTimeJul = dfJul.groupby('time').aggregate(sum)
tapTimeJul.reset_index(inplace = True)
tapTimeAug = dfAug.groupby('time').aggregate(sum)
tapTimeAug.reset_index(inplace = True)

counter = 0
tapTimeJul.head()
# Out:
#     time     count
# 0     -1  557700.0
# 1  00:00   20580.0
# 2  00:15   16208.0
# 3  00:30   10747.0
# 4  00:45    7598.0

# %%
tapTimeJul.drop(0, inplace = True)
tapTimeAug.drop(0, inplace = True)

tapTimeJul.head()
# Out:
#     time    count
# 1  00:00  20580.0
# 2  00:15  16208.0
# 3  00:30  10747.0
# 4  00:45   7598.0
# 5  01:00   5146.0

# %%
if counter == 0:
    tapTimeJul['time'] = pd.to_datetime(tapTimeJul['time'], format = '%H:%M').dt.time
    counter += 1
if counter == 1:
    tapTimeAug['time'] = pd.to_datetime(tapTimeAug['time'], format = '%H:%M').dt.time
    counter += 1

tapTimeJul.head()
# Out:
#        time    count
# 1  00:00:00  20580.0
# 2  00:15:00  16208.0
# 3  00:30:00  10747.0
# 4  00:45:00   7598.0
# 5  01:00:00   5146.0

# %%
tapTimeJul.plot(kind = 'bar', title = 'Amount of Taps for the Time of Day\nJuly Plot', x = 'time')

# %%
tapTimeAug.plot(kind = 'bar', title = 'Amount of Taps for the Time of Day\nAugust Plot', x = "time")

# %%
plt.plot(tapTimeJul['time'], tapTimeJul['count'], label = "July")
plt.plot(tapTimeAug['time'], tapTimeAug['count'], label = "August")

plt.xlabel('Time of Day')
plt.ylabel('Taps')
plt.title('Amount of Taps for the Time of Day\n Comparison')
plt.legend()
plt.show()

# %%
busesAug = dfAug[dfAug['mode'] == "bus"]
busLocAug = busesAug.groupby('loc').aggregate(sum)
busLocAug.reset_index(inplace = True)

busLocAug.head(5)
# Out:
#     loc      count
# 0    -1   400341.0
# 1  2000  1656742.0
# 2  2007    73941.0
# 3  2008    69338.0
# 4  2009    29418.0

# %%
busLocAug.drop(0, inplace = True)

busLocAug.head(5)
# Out:
#     loc      count
# 1  2000  1656742.0
# 2  2007    73941.0
# 3  2008    69338.0
# 4  2009    29418.0
# 5  2010   246969.0

# %%
busLocAug.plot(x = 'loc', y = 'count', kind='bar')

# %%
postcodes = pd.read_html("http://www.intosydneydirectory.com.au/sydney-postcodes.php")
postcodes = postcodes[1]
del postcodes[1]

# %%
postcodes.columns = ['suburb', 'postcode']
postcodes.sort_values('postcode', ascending = True, inplace = True)
postcodes.set_index('postcode', inplace = True)
postcodes.head()
# Out:
#                 suburb
# postcode
# 2000         Haymarket
# 2000            Sydney
# 2000       Dawes Point
# 2000        Barangaroo
# 2000      Sydney South

# %%
busLocAug = busLocAug.sort_values('count', ascending = False).head(5)

busLocAug.plot(x = 'loc', y = 'count', title = 'Top Bus Areas', kind = 'bar')

# %%
postcodes.loc[postcodes.index.isin([2000, 2150, 2022, 2031, 2010])]
# Out:
#                   suburb
# postcode
# 2000           Haymarket
# 2000              Sydney
# 2000         Dawes Point
# 2000          Barangaroo
# 2000        Sydney South
# 2000       Millers Point
# 2000           The Rocks
# 2010         Surry Hills
# 2010        Darlinghurst
# 2022         Queens Park
# 2022      Bondi Junction
# 2031            Randwick
# 2031            Clovelly
# 2150         Harris Park
# 2150          Parramatta

# %%
trainLocAug = dfAug[dfAug['mode'] == "train"]
trainLocAug = trainLocAug.groupby('loc').aggregate(sum)
trainLocAug.reset_index(inplace = True)

trainLocAug.head(5)
# Out:
#                    loc     count
# 0  Albion Park Station     973.0
# 1      Allawah Station   28414.0
# 2    Arncliffe Station   22647.0
# 3     Artarmon Station   71761.0
# 4     Ashfield Station  158958.0

# %%
trainLocAug = trainLocAug.sort_values('count', ascending = False).head(5)

trainLocAug.plot(x = 'loc', y = 'count', title = 'Top Train Stations', kind = 'bar')

# %%
ferryLocAug = dfAug[dfAug['mode'] == "ferry"]
ferryLocAug = ferryLocAug.groupby('loc').aggregate(sum)
ferryLocAug.reset_index(inplace = True)

ferryLocAug.head(5)
# Out:
#                   loc   count
# 0    Abbotsford Wharf  2072.0
# 1  Balmain East Wharf  4033.0
# 2       Balmain Wharf  4182.0
# 3      Cabarita Wharf  3425.0
# 4      Chiswick Wharf   904.0

# %%
ferryLocAug = ferryLocAug.sort_values('count', ascending = False).head(5)

ferryLocAug.plot(x = 'loc', y = 'count', title = 'Top Wharfs', kind = 'bar')

# %%
lightRailLocAug = dfAug[dfAug['mode'] == "lightrail"]
lightRailLocAug = lightRailLocAug.groupby('loc').aggregate(sum)
lightRailLocAug.reset_index(inplace = True)

lightRailLocAug.head(5)
# Out:
#                             loc    count
# 0          Arlington Light Rail   1625.0
# 1     Capitol Square Light Rail  33618.0
# 2    Central Station Light Rail  86113.0
# 3  Convention Centre Light Rail  10038.0
# 4      Dulwich Grove Light Rail    650.0

# %%
lightRailLocAug = lightRailLocAug.sort_values('count', ascending = False).head(5)

lightRailLocAug.plot(x = 'loc', y = 'count', title = 'Top Light Rail Stops', kind = 'bar')
